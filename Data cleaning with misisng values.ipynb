# %% [markdown]
# ### Data cleaning
# Nhi Le Thi
# #### Topic 4: Data cleaning with handle missing values
# #### What does the topic 4 have?
#     + Delete columns
#     + Drop duplicates
#     + Data types inconsistencies
#     + Handle missing categories values
#     + Handle missing continuous values
#     + KNN for missing value imputation
#     + MICE or Multiple imputation by Chained Equation
#     + Imputation ffill/ bfill

# %% [markdown]
# Load library, dataset and first rows

# %%
import numpy as np
import pandas as pd

# %%
df =pd.read_csv('unclean_data.csv', encoding= 'latin1')

# %%
df.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
df.isnull().sum()
# Out:
# movie_title                  0
# num_critic_for_reviews       0
# duration                     3
# DIRECTOR_facebook_likes      2
# actor_3_facebook_likes       0
# ACTOR_1_facebook_likes       0
# gross                        0
# num_voted_users              1
# Cast_Total_facebook_likes    2
# facenumber_in_poster         5
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# ACTOR_2_facebook_likes       1
# imdb_score                   0
# title_year.1                 7
# dtype: int64

# %%
count_missing = df.isnull().sum().sum()

# %%
count_values = np.product(df.shape)

# %%
# percentage missing value
percent_missing = (count_missing/count_values)*100
print('The percentage missing values is:', percent_missing, '%')
# Out:
# The percentage missing values is: 9.375 %

# %% [markdown]
# If the column has over 60% missing value, we could delete that column. However, be careful!

# %% [markdown]
# Drop duplicates
# + drop_duplicates()
# + keep = 'first'

# %%
df.head(4)
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# 2                   11000  200074175         275868.0
# 3                   27000  448130642        1144337.0
#
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated('movie_title')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# dtype: bool

# %%
df.shape
# Out:
# (14, 16)

# %%
df_drop_movie_duplicate = df.drop_duplicates('movie_title')

# %%
df_drop_movie_duplicate.shape
# Out:
# (13, 16)

# %% [markdown]
# Data types inconsistencies
# + change datatype after reading the csv
# + change datatype before reading the csv

# %%
# change datatype before reading
df1 = pd.read_csv('unclean_data.csv', dtype= {'duration': float}, encoding = 'latin1')

# %%
df1.duration.dtype
# Out:
# dtype('float64')

# %%
# change datatype after reading
df.dtypes
# Out:
# movie_title                   object
# num_critic_for_reviews         int64
# duration                     float64
# DIRECTOR_facebook_likes       object
# actor_3_facebook_likes         int64
# ACTOR_1_facebook_likes         int64
# gross                          int64
# num_voted_users              float64
# Cast_Total_facebook_likes    float64
# facenumber_in_poster         float64
# num_user_for_reviews           int64
# budget                         int64
# title_year                     int64
# ACTOR_2_facebook_likes       float64
# imdb_score                   float64
# title_year.1                 float64
# dtype: object

# %%
df.DIRECTOR_facebook_likes.dtypes
# Out:
# dtype('O')

# %%
df.DIRECTOR_facebook_likes.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10968/4008826209.py in <module>
# ----> 1 df.DIRECTOR_facebook_likes.astype(float)
#
# G:\Python\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# G:\Python\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
df.DIRECTOR_facebook_likes.str.contains('"475"')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10      NaN
# 11      NaN
# 12    False
# 13    False
# Name: DIRECTOR_facebook_likes, dtype: object

# %%
df.DIRECTOR_facebook_likes[4] = df.DIRECTOR_facebook_likes[4].replace('"', '')
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_10968/3535589470.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.DIRECTOR_facebook_likes[4] = df.DIRECTOR_facebook_likes[4].replace('"', '')

# %%
df.DIRECTOR_facebook_likes.astype(float).dtypes
# Out:
# dtype('float64')

# %% [markdown]
# Handle missing continuous values

# %%
df.head(4)
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# 2                   11000  200074175         275868.0
# 3                   27000  448130642        1144337.0
#
# ...

# %%
df.dtypes
# Out:
# movie_title                   object
# num_critic_for_reviews         int64
# duration                     float64
# DIRECTOR_facebook_likes       object
# actor_3_facebook_likes         int64
# ACTOR_1_facebook_likes         int64
# gross                          int64
# num_voted_users              float64
# Cast_Total_facebook_likes    float64
# facenumber_in_poster         float64
# num_user_for_reviews           int64
# budget                         int64
# title_year                     int64
# ACTOR_2_facebook_likes       float64
# imdb_score                   float64
# title_year.1                 float64
# dtype: object

# %%
df.shape
# Out:
# (14, 16)

# %% [markdown]
# Mean/ mode/ median()

# %%
df.duration
# Out:
# 0     178.0
# 1       NaN
# 2     148.0
# 3       NaN
# 4     132.0
# 5     156.0
# 6       NaN
# 7     141.0
# 8     141.0
# 9     153.0
# 10    183.0
# 11    169.0
# 12    106.0
# 13    151.0
# Name: duration, dtype: float64

# %%
df.duration.mean()
# Out:
# 150.72727272727272

# %%
df_mean= df.duration.fillna( df.duration.mean())

# %%
df_mean
# Out:
# 0     178.000000
# 1     150.727273
# 2     148.000000
# 3     150.727273
# 4     132.000000
# 5     156.000000
# 6     150.727273
# 7     141.000000
# 8     141.000000
# 9     153.000000
# 10    183.000000
# 11    169.000000
# 12    106.000000
# 13    151.000000
# Name: duration, dtype: float64

# %% [markdown]
# Linear regression

# %%
# split data
test = df[df['duration'].isna()]
train = df.dropna()

# %%
test.shape
# Out:
# (3, 16)

# %%
train.shape
# Out:
# (4, 16)

# %%
# prepare data
x_train = train.drop(['duration'], axis= 1)
y_train = train['duration']
x_test = test.drop(['duration'], axis =1)

# %%
# # model
# from sklearn.linear_model import LinearRegression
# linear = LinearRegression()
# linear.fit(x_train, y_train)

# # predict 
# y_predict = linear.predict(x_test)
# df.loc[df.duration.isnull(), 'duration'] = y_predcit

# %% [markdown]
# KNN for missing value imputation

# %%
df['duration'].fillna(method ='ffill')
# Out:
# 0     178.0
# 1     178.0
# 2     148.0
# 3     148.0
# 4     132.0
# 5     156.0
# 6     156.0
# 7     141.0
# 8     141.0
# 9     153.0
# 10    183.0
# 11    169.0
# 12    106.0
# 13    151.0
# Name: duration, dtype: float64

# %%
df['duration'].fillna(method ='bfill')
# Out:
# 0     178.0
# 1     148.0
# 2     148.0
# 3     132.0
# 4     132.0
# 5     156.0
# 6     141.0
# 7     141.0
# 8     141.0
# 9     153.0
# 10    183.0
# 11    169.0
# 12    106.0
# 13    151.0
# Name: duration, dtype: float64
